# %%
pwd
# Out:
# '/Users/ellismok/Desktop/Challenges/ca-school-enrollment-trend/Yearly Merged Employment Workbook'

# %%
# Dependencies and Setup
import pandas as pd
import pathlib
import csv
import scipy.stats as st
import numpy as np

# %%
# Create paths for csv

employment_2015_data = "../Merged Employment/Resources/merged_employment_yearly/Merged_Employment_2015.csv"
employment_2016_data = "../Merged Employment/Resources/merged_employment_yearly/Merged_Employment_2016.csv"
employment_2017_data = "../Merged Employment/Resources/merged_employment_yearly/Merged_Employment_2017.csv"
employment_2018_data = "../Merged Employment/Resources/merged_employment_yearly/Merged_Employment_2018.csv"
employment_2019_data = "../Merged Employment/Resources/merged_employment_yearly/Merged_Employment_2019.csv"

# %%
list_of_files = [
    "../Merged Employment/Resources/merged_employment_yearly/Merged_Employment_2015.csv",
    "../Merged Employment/Resources/merged_employment_yearly/Merged_Employment_2016.csv",
    "../Merged Employment/Resources/merged_employment_yearly/Merged_Employment_2017.csv",
    "../Merged Employment/Resources/merged_employment_yearly/Merged_Employment_2018.csv",
    "../Merged Employment/Resources/merged_employment_yearly/Merged_Employment_2019.csv"
]

# Format pd.read_csv(filename).assign(year=2015)
all_merged_df = []
for i,filename in enumerate(list_of_files):
    X1 = pd.read_csv(filename)
    X1["year"] = 2015 + i
    all_merged_df.append(X1)
    
# Combine the data into a single dataset
all_employment_data = pd.concat(all_merged_df)
all_employment_df = pd.DataFrame(all_employment_data)

# %%
# Save csv file 

all_employment_data.to_csv("../Merged Employment/Resources/merged_employment_yearly/all_employment_data.csv")

# %%
## Clean Data Set

# %%
#Final dataset for all years and all_employment_df

# %%
all_employment_df
# Out:
#      Unnamed: 0  Unnamed: 0.1  Total!!Estimate!!Population 16 years and over  \
# 0             0             1                                        74447.0
# 1             1             2                                        63117.0
# 2             2             3                                        60729.0
# 3             3             4                                        61495.0
# 4             4             5                                       100489.0
# ..          ...           ...                                            ...
# 211          39            40                                            NaN
# 212          40            41                                            NaN
# 213          41            42                                            NaN
# 214          42            43                                            NaN
# 215          43            44                                            NaN
#
#      Total!!Estimate!!Population 20 to 64 years  \
# 0                                       58032.0
# 1                                       47536.0
# 2                                       41043.0
# 3                                       46442.0
# 4                                       77187.0
# ..                                          ...
# 211                                         NaN
# 212                                         NaN
# 213                                         NaN
# 214                                         NaN
# 215                                         NaN
#
#      Employment/Population Ratio!!Estimate!!Population 16 years and over  \
# 0                                                 50.4
# 1                                                 58.9
# 2                                                 45.6
# 3                                                 63.4
# 4                                                 53.9
# ..                                                 ...
# 211                                                NaN
# 212                                                NaN
# 213                                                NaN
# 214                                                NaN
# 215                                                NaN
#
#      Employment/Population Ratio!!Estimate!!Population 20 to 64 years  \
# 0                                                 61.2
# 1                                                 72.4
# 2                                                 61.5
# 3                                                 76.7
# 4                                                 66.2
# ..                                                 ...
# 211                                                NaN
# 212                                                NaN
# 213                                                NaN
# 214                                                NaN
# 215                                                NaN
#
#      Unemployment rate!!Estimate!!Population 16 years and over  \
# 0                                                 14.7
# 1                                                  3.7
# 2                                                 11.9
# 3                                                  3.9
# 4                                                  9.6
# ..                                                 ...
# 211                                                NaN
# 212                                                NaN
# 213                                                NaN
# 214                                                NaN
# 215                                                NaN
#
#      Unemployment rate!!Estimate!!Population 20 to 64 years  NCESDist  year  \
# 0                                                 13.8         600014  2015
# 1                                                  3.3         600016  2015
# 2                                                 10.7         600017  2015
# 3                                                  3.5         600020  2015
# 4                                                  8.1         600027  2015
# ..                                                 ...            ...   ...
# 211                                                NaN         624660  2019
# 212                                                NaN         625150  2019
# 213                                                NaN         626310  2019
# 214                                                NaN         626880  2019
# 215                                                NaN         629270  2019
#
#     School District Type  Estimate!!Total!!Population 16 years and over  \
# 0                Unified                                            NaN
# 1                Unified                                            NaN
# 2                Unified                                            NaN
# 3                Unified                                            NaN
# 4                Unified                                            NaN
# ..                   ...                                            ...
# 211            Secondary                                       137172.0
# 212            Secondary                                       211497.0
# 213            Secondary                                        96912.0
# 214            Secondary                                        74329.0
# 215            Secondary                                       263863.0
#
#      Estimate!!Employment/Population Ratio!!Population 16 years and over  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 211                                               57.4
# 212                                               55.7
# 213                                               67.0
# 214                                               51.5
# 215                                               61.3
#
#      Estimate!!Unemployment rate!!Population 16 years and over  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 211                                                9.6
# 212                                                7.3
# 213                                                2.9
# 214                                                2.1
# 215                                                4.7
#
#      Estimate!!Total!!Population 20 to 64 years  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 211                                    106224.0
# 212                                    158512.0
# 213                                     75135.0
# 214                                     46552.0
# 215                                    197839.0
#
#      Estimate!!Employment/Population Ratio!!Population 20 to 64 years  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 211                                               68.9
# 212                                               69.3
# 213                                               79.8
# 214                                               71.1
# 215                                               74.9
#
#      Estimate!!Unemployment rate!!Population 20 to 64 years
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 211                                                8.5
# 212                                                6.8
# 213                                                2.7
# 214                                                2.4
# 215                                                4.5
#
# [1080 rows x 17 columns]

# %%
all_employment_df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1',
#        'Total!!Estimate!!Population 16 years and over',
#        'Total!!Estimate!!Population 20 to 64 years',
#        'Employment/Population Ratio!!Estimate!!Population 16 years and over',
#        'Employment/Population Ratio!!Estimate!!Population 20 to 64 years',
#        'Unemployment rate!!Estimate!!Population 16 years and over',
#        'Unemployment rate!!Estimate!!Population 20 to 64 years', 'NCESDist',
#        'year', 'School District Type',
#        'Estimate!!Total!!Population 16 years and over',
#        'Estimate!!Employment/Population Ratio!!Population 16 years and over',
#        'Estimate!!Unemployment rate!!Population 16 years and over',
#        'Estimate!!Total!!Population 20 to 64 years',
#        'Estimate!!Employment/Population Ratio!!Population 20 to 64 years',
#        'Estimate!!Unemployment rate!!Population 20 to 64 years'],
#       dtype='object')
