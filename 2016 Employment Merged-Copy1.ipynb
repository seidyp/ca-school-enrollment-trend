# %%
pwd
# Out:
# '/Users/ellismok/Desktop/Challenges/ca-school-enrollment-trend'

# %%
# Dependencies and Setup
import pandas as pd
import pathlib
import csv
import scipy.stats as st
import numpy as np

# %%
# Create paths for csv

employment_unified_2016_data = "Merged Employment/Resources/output_employment_data/Unified2016.csv"
employment_elementary_2016_data = "Merged Employment/Resources/output_employment_data/Elementary2016.csv"
employment_secondary_2016_data = "Merged Employment/Resources/output_employment_data/Secondary2016.csv"

# %%
# UNIFIED 2016

employment_unified_2016 = pd.read_csv(employment_unified_2016_data)
# pd.DataFrame(employment_unified_2016)

# %%
# ELEMENTARY 2016

employment_elementary_2016 = pd.read_csv(employment_elementary_2016_data)
# pd.DataFrame(employment_elementary_2016)

# %%
# SECONDARY 2016 

employment_secondary_2016 = pd.read_csv(employment_secondary_2016_data)
# pd.DataFrame(employment_secondary_2016)

# %%
list_of_files = [
    "Merged Employment/Resources/output_employment_data/Unified2016.csv",
    "Merged Employment/Resources/output_employment_data/Elementary2016.csv",
    "Merged Employment/Resources/output_employment_data/Secondary2016.csv"
]

# Format pd.read_csv(filename).assign(year=2016)
employment_2016_df = []
for i,filename in enumerate(list_of_files):
    X1 = pd.read_csv(filename)
    X1["year"] = 2016
    employment_2016_df.append(X1)
    
# Combine the data into a single dataset
employment_2016_data = pd.concat(employment_2016_df)
employment_2016_merged = pd.DataFrame(employment_2016_data)

# %%
# Save csv file 

employment_2016_merged.to_csv("Merged Employment/Resources/merged_employment_yearly/Merged_Employment_2016.csv")

# %%
employment_2016_merged
# Out:
#     Unnamed: 0  Total!!Estimate!!Population 16 years and over  \
# 0            1                                          82334
# 1            2                                          63598
# 2            3                                          63453
# 3            4                                          62993
# 4            5                                         100634
# ..         ...                                            ...
# 40          41                                         391423
# 41          42                                          97603
# 42          43                                          61209
# 43          44                                         175273
# 44          45                                         217047
#
#     Total!!Estimate!!RACE AND HISPANIC OR LATINO ORIGIN!!White alone  \
# 0                                               68715
# 1                                               45850
# 2                                               50460
# 3                                               38232
# 4                                               63493
# ..                                                ...
# 40                                             267769
# 41                                              85958
# 42                                              48924
# 43                                              83139
# 44                                             154685
#
#     Total!!Estimate!!RACE AND HISPANIC OR LATINO ORIGIN!!Black or African American alone  \
# 0                                          -999999999
# 1                                          -999999999
# 2                                          -999999999
# 3                                          -999999999
# 4                                          -999999999
# ..                                                ...
# 40                                              18094
# 41                                         -999999999
# 42                                         -999999999
# 43                                         -999999999
# 44                                               8070
#
#     Total!!Estimate!!RACE AND HISPANIC OR LATINO ORIGIN!!American Indian and Alaska Native alone  \
# 0                                          -999999999
# 1                                          -999999999
# 2                                          -999999999
# 3                                          -999999999
# 4                                          -999999999
# ..                                                ...
# 40                                         -999999999
# 41                                         -999999999
# 42                                         -999999999
# 43                                         -999999999
# 44                                         -999999999
#
#     Total!!Estimate!!RACE AND HISPANIC OR LATINO ORIGIN!!Asian alone  \
# 0                                          -999999999
# 1                                                5919
# 2                                          -999999999
# 3                                          -999999999
# 4                                          -999999999
# ..                                                ...
# 40                                              60584
# 41                                         -999999999
# 42                                         -999999999
# 43                                              12105
# 44                                              25965
#
#     Total!!Estimate!!RACE AND HISPANIC OR LATINO ORIGIN!!Native Hawaiian and Other Pacific Islander alone  \
# 0                                          -999999999
# 1                                          -999999999
# 2                                          -999999999
# 3                                          -999999999
# 4                                          -999999999
# ..                                                ...
# 40                                         -999999999
# 41                                         -999999999
# 42                                         -999999999
# 43                                         -999999999
# 44                                         -999999999
#
#     Total!!Estimate!!RACE AND HISPANIC OR LATINO ORIGIN!!Some other race alone  \
# 0                                          -999999999
# 1                                          -999999999
# 2                                          -999999999
# 3                                          -999999999
# 4                                          -999999999
# ..                                                ...
# 40                                              27460
# 41                                         -999999999
# 42                                         -999999999
# 43                                              68519
# 44                                              16255
#
#     Total!!Estimate!!RACE AND HISPANIC OR LATINO ORIGIN!!Two or more races  \
# 0                                          -999999999
# 1                                          -999999999
# 2                                          -999999999
# 3                                          -999999999
# 4                                          -999999999
# ..                                                ...
# 40                                              13621
# 41                                         -999999999
# 42                                         -999999999
# 43                                         -999999999
# 44                                         -999999999
#
#     Total!!Estimate!!Hispanic or Latino origin (of any race)  ...  \
# 0                                               42536         ...
# 1                                               21048         ...
# 2                                               20642         ...
# 3                                          -999999999         ...
# 4                                               41790         ...
# ..                                                ...         ...
# 40                                             232431         ...
# 41                                         -999999999         ...
# 42                                              34975         ...
# 43                                             119953         ...
# 44                                              65553         ...
#
#     Unemployment rate!!Estimate!!RACE AND HISPANIC OR LATINO ORIGIN!!Two or more races  \
# 0                                        -999999999.0
# 1                                        -999999999.0
# 2                                        -999999999.0
# 3                                        -999999999.0
# 4                                        -999999999.0
# ..                                                ...
# 40                                               10.6
# 41                                       -999999999.0
# 42                                       -999999999.0
# 43                                       -999999999.0
# 44                                       -999999999.0
#
#     Unemployment rate!!Estimate!!Hispanic or Latino origin (of any race)  \
# 0                                                 6.9
# 1                                                 4.6
# 2                                                20.0
# 3                                        -999999999.0
# 4                                                 6.3
# ..                                                ...
# 40                                               11.3
# 41                                       -999999999.0
# 42                                                9.2
# 43                                                5.1
# 44                                                8.1
#
#     Unemployment rate!!Estimate!!White alone, not Hispanic or Latino  \
# 0                                                10.9
# 1                                                 2.2
# 2                                                 9.9
# 3                                                 4.7
# 4                                                10.9
# ..                                                ...
# 40                                                6.8
# 41                                                4.2
# 42                                                5.0
# 43                                                6.4
# 44                                                5.0
#
#     Unemployment rate!!Estimate!!Population 20 to 64 years  STATE  \
# 0                                                 7.7           6
# 1                                                 3.4           6
# 2                                                13.1           6
# 3                                                 3.5           6
# 4                                                 7.1           6
# ..                                                ...         ...
# 40                                                9.0           6
# 41                                                4.2           6
# 42                                                7.2           6
# 43                                                5.0           6
# 44                                                5.9           6
#
#     SCHOOL DISTRICT (UNIFIED)  NCESDist  year  SCHOOL DISTRICT (ELEMENTARY)  \
# 0                        14.0    600014  2016                           NaN
# 1                        16.0    600016  2016                           NaN
# 2                        17.0    600017  2016                           NaN
# 3                        20.0    600020  2016                           NaN
# 4                        27.0    600027  2016                           NaN
# ..                        ...       ...   ...                           ...
# 40                        NaN    638640  2016                           NaN
# 41                        NaN    638790  2016                           NaN
# 42                        NaN    639930  2016                           NaN
# 43                        NaN    642480  2016                           NaN
# 44                        NaN    642510  2016                           NaN
#
#     SCHOOL DISTRICT (SECONDARY)
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ..                          ...
# 40                      38640.0
# 41                      38790.0
# 42                      39930.0
# 43                      42480.0
# 44                      42510.0
#
# [214 rows x 40 columns]
