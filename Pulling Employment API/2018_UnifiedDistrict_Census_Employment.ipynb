# %%
import pandas as pd
import requests

# %%
url="https://api.census.gov/data/2018/acs/acs1/subject?get=group(S2301)&for=school%20district%20(unified)&in=state:06"

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
response_json = response.json()

# %%
unifiedschool_df = pd.DataFrame(response_json,columns=response_json[0]).drop(0)
unifiedschool_df
# Out:
#                GEO_ID S2301_C01_001E S2301_C01_001M S2301_C02_001E  \
# 1    9700000US0604740         109560           1896           60.4
# 2    9700000US0634710          63248           5649           64.7
# 3    9700000US0604290          50539           3443           58.4
# 4    9700000US0610620          71904           2236           53.4
# 5    9700000US0611110         166990           4015           52.4
# ..                ...            ...            ...            ...
# 116  9700000US0622230         135023           7111           59.3
# 117  9700000US0625830          52738           3451           66.0
# 118  9700000US0633150         215142           8576           63.1
# 119  9700000US0638010         151285           6832           60.2
# 120  9700000US0643080          53395           2211           63.7
#
#     S2301_C02_001M S2301_C03_001E S2301_C03_001M S2301_C04_001E  \
# 1              2.5           58.1            2.4            3.9
# 2              3.2           62.3            3.2            3.8
# 3              3.8           56.1            3.7            3.4
# 4              3.5           50.2            3.2            5.8
# 5              2.5           46.8            2.6           10.7
# ..             ...            ...            ...            ...
# 116            2.5           54.9            2.6            7.2
# 117            2.9           63.8            3.0            3.4
# 118            2.1           59.4            2.2            5.5
# 119            2.3           55.8            2.5            7.3
# 120            3.7           60.7            4.2            4.7
#
#     S2301_C04_001M S2301_C01_002E  ... S2301_C01_035EA S2301_C01_035MA  \
# 1              1.1          13361  ...            None            None
# 2              1.5           2582  ...            None            None
# 3              1.9           2779  ...            None            None
# 4              2.0          11523  ...               N               N
# 5              2.2           6463  ...            None            None
# ..             ...            ...  ...             ...             ...
# 116            1.7           9182  ...            None            None
# 117            1.7           3406  ...            None            None
# 118            1.3          22415  ...            None            None
# 119            1.5          13202  ...            None            None
# 120            2.0           4069  ...            None            None
#
#     S2301_C02_035EA S2301_C02_035MA S2301_C03_035EA S2301_C03_035MA  \
# 1              None            None            None            None
# 2              None            None            None            None
# 3              None            None            None            None
# 4                 N               N               N               N
# 5              None            None            None            None
# ..              ...             ...             ...             ...
# 116            None            None            None            None
# 117            None            None            None            None
# 118            None            None            None            None
# 119            None            None            None            None
# 120            None            None            None            None
#
#     S2301_C04_035EA S2301_C04_035MA state school district (unified)
# 1              None            None    06                     04740
# 2              None            None    06                     34710
# 3              None            None    06                     04290
# 4                 N               N    06                     10620
# 5              None            None    06                     11110
# ..              ...             ...   ...                       ...
# 116            None            None    06                     22230
# 117            None            None    06                     25830
# 118            None            None    06                     33150
# 119            None            None    06                     38010
# 120            None            None    06                     43080
#
# [120 rows x 564 columns]

# %%
unifiedschool_df.loc[unifiedschool_df["NAME"]=="Hesperia Unified School District, California"]
# Out:
#               GEO_ID S2301_C01_001E S2301_C01_001M S2301_C02_001E  \
# 35  9700000US0600014          77198           4075           56.7
#
#    S2301_C02_001M S2301_C03_001E S2301_C03_001M S2301_C04_001E S2301_C04_001M  \
# 35            3.7           51.6            3.4            8.5            2.5
#
#    S2301_C01_002E  ... S2301_C01_035EA S2301_C01_035MA S2301_C02_035EA  \
# 35           5259  ...            None            None            None
#
#    S2301_C02_035MA S2301_C03_035EA S2301_C03_035MA S2301_C04_035EA  \
# 35            None            None            None            None
#
#    S2301_C04_035MA state school district (unified)
# 35            None    06                     00014
#
# [1 rows x 564 columns]

# %%
## REMAME

# %%
variableurl = "https://api.census.gov/data/2018/acs/acs1/subject/variables.json"

# %%
variables_json = requests.get(variableurl).json()

# %%
assert len(new_labels) == len(unifiedschool_df.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-914d1314f5bf> in <module>
# ----> 1 assert len(new_labels) == len(unifiedschool_df.columns)
#
# NameError: name 'new_labels' is not defined
