# %%
pwd
# Out:
# '/Users/ellismok/Desktop/Challenges/ca-school-enrollment-trend'

# %%
# Dependencies and Setup
import pandas as pd
import pathlib
import csv
import scipy.stats as st
import numpy as np

# %%
# Create paths for csv

employment_unified_2019_data = "Merged Employment/Resources/output_employment_data/Unified2019.csv"
employment_elementary_2019_data = "Merged Employment/Resources/output_employment_data/Elementary2019.csv"
employment_secondary_2019_data = "Merged Employment/Resources/output_employment_data/Secondary2019.csv"

# %%
# UNIFIED 2019

employment_unified_2019 = pd.read_csv(employment_unified_2019_data)
# pd.DataFrame(employment_unified_2019)

# %%
# ELEMENTARY 2019

employment_elementary_2019 = pd.read_csv(employment_elementary_2019_data)
# pd.DataFrame(employment_elementary_2019)

# %%
# SECONDARY 2019 

employment_secondary_2019 = pd.read_csv(employment_secondary_2019_data)
# pd.DataFrame(employment_secondary_2019)

# %%
list_of_files = [
    "Merged Employment/Resources/output_employment_data/Unified2019.csv",
    "Merged Employment/Resources/output_employment_data/Elementary2019.csv",
    "Merged Employment/Resources/output_employment_data/Secondary2019.csv"
]

# Format pd.read_csv(filename).assign(year=2019)
employment_2019_df = []
for i,filename in enumerate(list_of_files):
    X1 = pd.read_csv(filename)
    X1["year"] = 2019
    employment_2019_df.append(X1)
    
# Combine the data into a single dataset
employment_2019_data = pd.concat(employment_2019_df)
employment_2019_merged = pd.DataFrame(employment_2019_data)

# %%
# Save csv file 

employment_2019_merged.to_csv("Merged Employment/Resources/merged_employment_yearly/Merged_Employment_2019.csv")

# %%
employment_2019_merged
# Out:
#     Unnamed: 0         Geography  \
# 0            1  9700000US0632070
# 1            2  9700000US0632550
# 2            3  9700000US0633150
# 3            4  9700000US0633750
# 4            5  9700000US0633840
# ..         ...               ...
# 39          40  9600000US0624660
# 40          41  9600000US0625150
# 41          42  9600000US0626310
# 42          43  9600000US0626880
# 43          44  9600000US0629270
#
#                                                  NAME  \
# 0        Redlands Unified School District, California
# 1   West Contra Costa Unified School District, Cal...
# 2       Riverside Unified School District, California
# 3         Rowland Unified School District, California
# 4   Sacramento City Unified School District, Calif...
# ..                                                ...
# 39      Merced Union High School District, California
# 40      Modesto City High School District, California
# 41  Mountain View-Los Altos Union School District,...
# 42  Nevada Joint Union High School District, Calif...
# 43      Oxnard Union High School District, California
#
#     Estimate!!Total!!Population 16 years and over  \
# 0                                          103753
# 1                                          205097
# 2                                          215389
# 3                                           87017
# 4                                          274468
# ..                                            ...
# 39                                         137172
# 40                                         211497
# 41                                          96912
# 42                                          74329
# 43                                         263863
#
#     Estimate!!Total!!Population 16 years and over!!RACE AND HISPANIC OR LATINO ORIGIN!!White alone  \
# 0                                               75568
# 1                                               65715
# 2                                              123698
# 3                                               20198
# 4                                              146375
# ..                                                ...
# 39                                              62507
# 40                                             165844
# 41                                              55075
# 42                                              69778
# 43                                             206663
#
#     Estimate!!Total!!Population 16 years and over!!RACE AND HISPANIC OR LATINO ORIGIN!!Black or African American alone  \
# 0                                          -999999999
# 1                                               32732
# 2                                               14620
# 3                                          -999999999
# 4                                               29800
# ..                                                ...
# 39                                               4622
# 40                                         -999999999
# 41                                         -999999999
# 42                                         -999999999
# 43                                               7449
#
#     Estimate!!Total!!Population 16 years and over!!RACE AND HISPANIC OR LATINO ORIGIN!!American Indian and Alaska Native alone  \
# 0                                          -999999999
# 1                                          -999999999
# 2                                          -999999999
# 3                                          -999999999
# 4                                          -999999999
# ..                                                ...
# 39                                         -999999999
# 40                                         -999999999
# 41                                         -999999999
# 42                                         -999999999
# 43                                         -999999999
#
#     Estimate!!Total!!Population 16 years and over!!RACE AND HISPANIC OR LATINO ORIGIN!!Asian alone  \
# 0                                          -999999999
# 1                                               44059
# 2                                               19921
# 3                                               41285
# 4                                               49604
# ..                                                ...
# 39                                              13248
# 40                                         -999999999
# 41                                              32137
# 42                                         -999999999
# 43                                              24435
#
#     Estimate!!Total!!Population 16 years and over!!RACE AND HISPANIC OR LATINO ORIGIN!!Native Hawaiian and Other Pacific Islander alone  \
# 0                                          -999999999
# 1                                          -999999999
# 2                                          -999999999
# 3                                          -999999999
# 4                                          -999999999
# ..                                                ...
# 39                                         -999999999
# 40                                         -999999999
# 41                                         -999999999
# 42                                         -999999999
# 43                                         -999999999
#
#     Estimate!!Total!!Population 16 years and over!!RACE AND HISPANIC OR LATINO ORIGIN!!Some other race alone  \
# 0                                          -999999999
# 1                                               51712
# 2                                               44992
# 3                                               21700
# 4                                               27093
# ..                                                ...
# 39                                              50924
# 40                                              11796
# 41                                         -999999999
# 42                                         -999999999
# 43                                              15294
#
#     ...  \
# 0   ...
# 1   ...
# 2   ...
# 3   ...
# 4   ...
# ..  ...
# 39  ...
# 40  ...
# 41  ...
# 42  ...
# 43  ...
#
#     Estimate!!Unemployment rate!!Population 16 years and over!!RACE AND HISPANIC OR LATINO ORIGIN!!Hispanic or Latino origin (of any race)  \
# 0                                                 4.9
# 1                                                 3.3
# 2                                                 5.5
# 3                                                 5.5
# 4                                                 7.3
# ..                                                ...
# 39                                               11.5
# 40                                               10.0
# 41                                       -999999999.0
# 42                                       -999999999.0
# 43                                                4.3
#
#     Estimate!!Unemployment rate!!Population 16 years and over!!RACE AND HISPANIC OR LATINO ORIGIN!!White alone, not Hispanic or Latino  \
# 0                                                 6.7
# 1                                                 3.2
# 2                                                 3.4
# 3                                                 6.1
# 4                                                 5.5
# ..                                                ...
# 39                                                6.0
# 40                                                6.3
# 41                                                2.8
# 42                                                2.5
# 43                                                3.9
#
#     Estimate!!Unemployment rate!!Population 20 to 64 years  STATE  \
# 0                                                 5.2           6
# 1                                                 2.7           6
# 2                                                 4.4           6
# 3                                                 6.5           6
# 4                                                 5.5           6
# ..                                                ...         ...
# 39                                                8.5           6
# 40                                                6.8           6
# 41                                                2.7           6
# 42                                                2.4           6
# 43                                                4.5           6
#
#     SCHOOL DISTRICT (UNIFIED)                                       District  \
# 0                     32070.0               Redlands Unified School District
# 1                     32550.0      West Contra Costa Unified School District
# 2                     33150.0              Riverside Unified School District
# 3                     33750.0                Rowland Unified School District
# 4                     33840.0        Sacramento City Unified School District
# ..                        ...                                            ...
# 39                        NaN              Merced Union High School District
# 40                        NaN              Modesto City High School District
# 41                        NaN  Mountain View-Los Altos Union School District
# 42                        NaN        Nevada Joint Union High School District
# 43                        NaN              Oxnard Union High School District
#
#     NCESDist  year  SCHOOL DISTRICT (ELEMENTARY)  SCHOOL DISTRICT (SECONDARY)
# 0     632070  2019                           NaN                          NaN
# 1     632550  2019                           NaN                          NaN
# 2     633150  2019                           NaN                          NaN
# 3     633750  2019                           NaN                          NaN
# 4     633840  2019                           NaN                          NaN
# ..       ...   ...                           ...                          ...
# 39    624660  2019                           NaN                      24660.0
# 40    625150  2019                           NaN                      25150.0
# 41    626310  2019                           NaN                      26310.0
# 42    626880  2019                           NaN                      26880.0
# 43    629270  2019                           NaN                      29270.0
#
# [216 rows x 43 columns]
